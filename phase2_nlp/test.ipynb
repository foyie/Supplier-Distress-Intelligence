# %%
import pandas as pd
df = pd.read_parquet("/Users/chandrimadas/projects/supplier-distress/data/processed/feature_matrix_full.csv")
print(df.shape)                        # should be (1000+, 25+)
print(df["label_6m"].value_counts())   # check distress rate ~20-35%
print(df.isnull().mean().sort_values(ascending=False).head(10))  # check coverage
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_parquet("/Users/chandrimadas/projects/supplier-distress/data/processed/feature_matrix_full.csv")
#       3 print(df.shape)                        # should be (1000+, 25+)
#       4 print(df["label_6m"].value_counts())   # check distress rate ~20-35%
#       5 print(df.isnull().mean().sort_values(ascending=False).head(10))  # check coverage
#
# File ~/projects/supplier-distress/venv/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
# ...
